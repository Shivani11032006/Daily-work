# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivani11032006/Daily-work/blob/main/Drag_Quantity_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import numpy as np

# %%
csv_file = '/content/patient_drag_quantity_data_with_30_features.csv.zmdownload'

# %%
df = pd.read_csv(csv_file)
print(df)
# Out:
#       Drag Quantity  Age  Gender  Height  Weight Region Grade Level  \
# 0          3.162938   18  Female     172      45  Urban     Grade 1
# 1          1.376374   17  Female      98      51  Urban     Grade 5
# 2          3.011316    9    Male     121      51  Urban     Grade 6
# 3          2.481289   14  Female     108      34  Rural     Grade 2
# 4          4.518977    8  Female     132      65  Urban     Grade 5
# ...             ...  ...     ...     ...     ...    ...         ...
# 3386       2.321579    5    Male     137      16  Urban     Grade 7
# 3387       1.921340   18  Female     174      47  Rural     Grade 4
# 3388       2.404777    7  Female     111      38  Urban     Grade 8
# 3389       2.720573   11    Male     170      61  Rural     Grade 2
# 3390       4.114114   18    Male     113      36  Urban     Grade 4
#
#       Num Siblings  Parent Health  Household Type  ...  Mother Education  \
# 0                1              1               0  ...   Bachelor Degree
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3391 entries, 0 to 3390
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Drag Quantity            3391 non-null   float64
#  1   Age                      3391 non-null   int64
#  2   Gender                   3391 non-null   object
#  3   Height                   3391 non-null   int64
#  4   Weight                   3391 non-null   int64
#  5   Region                   3391 non-null   object
#  6   Grade Level              3391 non-null   object
#  7   Num Siblings             3391 non-null   int64
#  8   Parent Health            3391 non-null   int64
#  9   Household Type           3391 non-null   int64
#  10  Asthma History           3391 non-null   int64
#  11  Allergy History          3391 non-null   int64
#  12  Chronic Disease History  3391 non-null   int64
#  13  Family Income            3391 non-null   int64
# ...

# %%
df.head()
# Out:
#    Drag Quantity  Age  Gender  Height  Weight Region Grade Level  \
# 0       3.162938   18  Female     172      45  Urban     Grade 1
# 1       1.376374   17  Female      98      51  Urban     Grade 5
# 2       3.011316    9    Male     121      51  Urban     Grade 6
# 3       2.481289   14  Female     108      34  Rural     Grade 2
# 4       4.518977    8  Female     132      65  Urban     Grade 5
#
#    Num Siblings  Parent Health  Household Type  ...  Mother Education  \
# 0             1              1               0  ...   Bachelor Degree
# 1             4              1               0  ...   Bachelor Degree
# 2             5              1               0  ...     Master Degree
# 3             2              1               1  ...       High School
# 4             4              0               0  ...  Associate Degree
#
#    Father Education  Num Chronic Conditions  Screen Time    BMI  \
# 0       High School                       3     5.395818  15.21
# ...

# %%
df.isnull().sum()
# Out:
# Drag Quantity              0
# Age                        0
# Gender                     0
# Height                     0
# Weight                     0
# Region                     0
# Grade Level                0
# Num Siblings               0
# Parent Health              0
# Household Type             0
# Asthma History             0
# Allergy History            0
# Chronic Disease History    0
# Family Income              0
# Access to Healthcare       0
# Mother Education           0
# Father Education           0
# Num Chronic Conditions     0
# Screen Time                0
# BMI                        0
# Exercise Frequency         0
# Diet Quality               0
# Sleep Hours                0
# Chronic Medication         1
# Allergic Medication        1
# dtype: int64
