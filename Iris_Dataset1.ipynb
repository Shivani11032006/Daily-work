# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivani11032006/Daily-work/blob/main/Iris_Dataset1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_name = '/content/iris.csv'

# %%
import pandas as pd
iris = pd.read_csv(file_name)

# %%
iris
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing

# %%
iris.head()
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           5.0          3.6           1.4          0.2  setosa

# %%
iris.isnull()
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# 0         False         False        False         False        False    False
# 1         False         False        False         False        False    False
# 2         False         False        False         False        False    False
# 3         False         False        False         False        False    False
# 4         False         False        False         False        False    False
# ..          ...           ...          ...           ...          ...      ...
# 145       False         False        False         False        False    False
# 146       False         False        False         False        False    False
# 147       False         False        False         False        False    False
# 148       False         False        False         False        False    False
# 149       False         False        False         False        False    False
#
# [150 rows x 6 columns]

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    150 non-null    int64
#  1   Sepal.Length  150 non-null    float64
#  2   Sepal.Width   150 non-null    float64
#  3   Petal.Length  150 non-null    float64
#  4   Petal.Width   150 non-null    float64
#  5   Species       150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
label_encoder = preprocessing.LabelEncoder()
iris['Species'] = label_encoder.fit_transform(iris['Species'])
iris['Species']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int64

# %%
iris = iris.rename(columns={'SepalLengthCm': 'SepalLength', 'SepalWidthCm': 'SepalWidth', 'PetalLengthCm': 'PetalLength', 'PetalWidthCm': 'PetalWidth', 'Species' : 'Flowers_types'})

# %%
iris
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#      Flowers_types
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...

# %%
iris = iris.rename(columns={'Species' : 'Flowers_types'})

# %%
iris
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#      Flowers_types
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...

# %%
label_encoder = preprocessing.LabelEncoder()
iris['Flowers_types'] = label_encoder.fit_transform(iris['Flowers_types'])
iris['Flowers_types']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Flowers_types, Length: 150, dtype: int64

# %%
x=iris.iloc[:,0:4]

# %%
x
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length
# 0             1           5.1          3.5           1.4
# 1             2           4.9          3.0           1.4
# 2             3           4.7          3.2           1.3
# 3             4           4.6          3.1           1.5
# 4             5           5.0          3.6           1.4
# ..          ...           ...          ...           ...
# 145         146           6.7          3.0           5.2
# 146         147           6.3          2.5           5.0
# 147         148           6.5          3.0           5.2
# 148         149           6.2          3.4           5.4
# 149         150           5.9          3.0           5.1
#
# [150 rows x 4 columns]

# %%
y=iris['Flowers_types']

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Flowers_types, Length: 150, dtype: int64

# %%
colnames = list(iris.columns)

# %%
colnames
# Out:
# ['Unnamed: 0',
#  'Sepal.Length',
#  'Sepal.Width',
#  'Petal.Length',
#  'Petal.Width',
#  'Flowers_types']

# %%
from sklearn.tree import DecisionTreeClassifier
model_gini = DecisionTreeClassifier(criterion='gini', max_depth=3)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)

# %%
x_test
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length
# 128         129           6.4          2.8           5.6
# 11           12           4.8          3.4           1.6
# 118         119           7.7          2.6           6.9
# 15           16           5.7          4.4           1.5
# 123         124           6.3          2.7           4.9
# 135         136           7.7          3.0           6.1
# 32           33           5.2          4.1           1.5
# 1             2           4.9          3.0           1.4
# 116         117           6.5          3.0           5.5
# 45           46           4.8          3.0           1.4
# 40           41           5.0          3.5           1.3
# 115         116           6.4          3.2           5.3
# 26           27           5.0          3.4           1.6
# 28           29           5.2          3.4           1.4
# 145         146           6.7          3.0           5.2
# ...

# %%
model_gini.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
preds = model_gini.predict(x_test)
print(preds)
# Out:
# [2 0 2 0 2 2 0 0 2 0 0 2 0 0 2 1 1 1 2 2 2 0 2 0 1 2 1 0 1 2]

# %%
np.mean(preds==y_test)
# Out:
# 1.0

# %%
x=iris.iloc[:,0:4]

# %%
x
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length
# 0             1           5.1          3.5           1.4
# 1             2           4.9          3.0           1.4
# 2             3           4.7          3.2           1.3
# 3             4           4.6          3.1           1.5
# 4             5           5.0          3.6           1.4
# ..          ...           ...          ...           ...
# 145         146           6.7          3.0           5.2
# 146         147           6.3          2.5           5.0
# 147         148           6.5          3.0           5.2
# 148         149           6.2          3.4           5.4
# 149         150           5.9          3.0           5.1
#
# [150 rows x 4 columns]
